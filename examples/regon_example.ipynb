# %% [markdown]
# # REGON Scraper example
#
# This module is used to scrape information from the [REGON database](https://wyszukiwarkaregon.stat.gov.pl/appBIR/index.aspx). The REGON database is a register of entities operating in Poland, including companies, institutions, and organizations.
#
# The module is used to create a web scraper that scrapes information about entities. The scraper is implemented using the Selenium package in Python, which allows for automated web browsing.
#
# Overall, the module can be used to automatically scrape information about entities operating in Poland from the REGON database, making it useful for research, data analysis, and other applications.

# %% [markdown]
# ## Usage
# A simple example of the module's use.

# %%
from WebCrawler.scrapers import RegonScraper

scraper = RegonScraper()
entities, local_entities, pkd = scraper.get_entity_info('7630003498', 'NIP')

# %% [markdown]
# ### Legal/Physical entities

# %%
entities
# Out:
#        regon         nip                   nazwa      forma_prawna
# 0  570107305  7630003498  "AMICA SPÓŁKA AKCYJNA"  1 - OSOBA PRAWNA  \
#
#         sz_forma_prawna                                    forma_wlasnosci
# 0  116 - SPÓŁKI AKCYJNE  225 - WŁASNOŚĆ MIESZANA W SEKTORZE PRYWATNYM Z...  \
#
#      kraj    wojewodztwo       powiat   gmina miejscowosc            ulica
# 0  POLSKA  WIELKOPOLSKIE  szamotulski  Wronki      Wronki  ul. Mickiewicza  \
#
#    nr kod_pocztowy
# 0  52       64-510

# %% [markdown]
# ### Local entities

# %%
local_entities
# Out:
#             regon regon j.nadrzędnej nip j.nadrzędnej
# 0  57010730500028          570107305       7630003498  \
#
#                                              nazwa      forma_prawna
# 0  AMICA WRONKI SPÓŁKA AKCYJNA ODDZIAŁ WE WRONKACH  1 - OSOBA PRAWNA  \
#
#         sz_forma_prawna                                    forma_wlasnosci
# 0  116 - SPÓŁKI AKCYJNE  225 - WŁASNOŚĆ MIESZANA W SEKTORZE PRYWATNYM Z...  \
#
#      kraj    wojewodztwo       powiat   gmina miejscowosc      ulica   nr
# 0  POLSKA  WIELKOPOLSKIE  szamotulski  Wronki      Wronki  ul. Leśna  15A  \
#
#   kod_pocztowy
# 0       64-510

# %% [markdown]
# ### PKD

# %%
pkd
# Out:
#              regon    kod                                              nazwa
# 0        570107305  2751Z  PRODUKCJA ELEKTRYCZNEGO SPRZĘTU GOSPODARSTWA D...
# 1        570107305  4641Z               SPRZEDAŻ HURTOWA WYROBÓW TEKSTYLNYCH
# 2        570107305  4642Z                  SPRZEDAŻ HURTOWA ODZIEŻY I OBUWIA
# 3        570107305  4643Z  SPRZEDAŻ HURTOWA ELEKTRYCZNYCH ARTYKUŁÓW UŻYTK...
# 4        570107305  4644Z  SPRZEDAŻ HURTOWA WYROBÓW PORCELANOWYCH, CERAMI...
# 5        570107305  4645Z               SPRZEDAŻ HURTOWA PERFUM I KOSMETYKÓW
# 6        570107305  4646Z  SPRZEDAŻ HURTOWA WYROBÓW FARMACEUTYCZNYCH I ME...
# 7        570107305  4647Z  SPRZEDAŻ HURTOWA MEBLI, DYWANÓW I SPRZĘTU OŚWI...
# 8        570107305  4648Z     SPRZEDAŻ HURTOWA ZEGARKÓW, ZEGARÓW I BIŻUTERII
# 9        570107305  4649Z  SPRZEDAŻ HURTOWA POZOSTAŁYCH ARTYKUŁÓW UŻYTKU ...
# 10       570107305  5210A      MAGAZYNOWANIE I PRZECHOWYWANIE PALIW GAZOWYCH
# 11       570107305  5210B  MAGAZYNOWANIE I PRZECHOWYWANIE POZOSTAŁYCH TOW...
# 12       570107305  5221Z  DZIAŁALNOŚĆ USŁUGOWA WSPOMAGAJĄCA TRANSPORT LĄ...
# 13       570107305  5222A  DZIAŁALNOŚĆ USŁUGOWA WSPOMAGAJĄCA TRANSPORT MO...
# 14       570107305  5222B  DZIAŁALNOŚĆ USŁUGOWA WSPOMAGAJĄCA TRANSPORT ŚR...
# 15       570107305  5223Z  DZIAŁALNOŚĆ USŁUGOWA WSPOMAGAJĄCA TRANSPORT LO...
# 16       570107305  5224A             PRZEŁADUNEK TOWARÓW W PORTACH MORSKICH
# 17       570107305  5224B         PRZEŁADUNEK TOWARÓW W PORTACH ŚRÓDLĄDOWYCH
# 18       570107305  5224C  PRZEŁADUNEK TOWARÓW W POZOSTAŁYCH PUNKTACH PRZ...
# 19       570107305  5229A        DZIAŁALNOŚĆ MORSKICH AGENCJI TRANSPORTOWYCH
# 20       570107305  5229B    DZIAŁALNOŚĆ ŚRÓDLĄDOWYCH AGENCJI TRANSPORTOWYCH
# 21       570107305  5229C     DZIAŁALNOŚĆ POZOSTAŁYCH AGENCJI TRANSPORTOWYCH
# 22       570107305  6491Z                                  LEASING FINANSOWY
# 23       570107305  6492Z                POZOSTAŁE FORMY UDZIELANIA KREDYTÓW
# 24       570107305  6499Z  POZOSTAŁA FINANSOWA DZIAŁALNOŚĆ USŁUGOWA, GDZI...
# 25       570107305  6920Z  DZIAŁALNOŚĆ RACHUNKOWO-KSIĘGOWA; DORADZTWO POD...
# 26       570107305  7010Z  DZIAŁALNOŚĆ FIRM CENTRALNYCH (HEAD OFFICES) I ...
# 27       570107305  7711Z  WYNAJEM I DZIERŻAWA SAMOCHODÓW OSOBOWYCH I FUR...
# 28       570107305  7712Z  WYNAJEM I DZIERŻAWA POZOSTAŁYCH POJAZDÓW SAMOC...
# 29       570107305  8299Z  POZOSTAŁA DZIAŁALNOŚĆ WSPOMAGAJĄCA PROWADZENIE...
# 30       570107305  9521Z  NAPRAWA I KONSERWACJA ELEKTRONICZNEGO SPRZĘTU ...
# 31       570107305  9522Z  NAPRAWA I KONSERWACJA URZĄDZEŃ GOSPODARSTWA DO...
# 32       570107305  9523Z                NAPRAWA OBUWIA I WYROBÓW SKÓRZANYCH
# 33       570107305  9524Z  NAPRAWA I KONSERWACJA MEBLI I WYPOSAŻENIA DOMO...
# 34       570107305  9525Z           NAPRAWA ZEGARÓW, ZEGARKÓW ORAZ BIŻUTERII
# 35       570107305  9529Z  NAPRAWA POZOSTAŁYCH ARTYKUŁÓW UŻYTKU OSOBISTEG...
# 36  57010730500028  2751Z  PRODUKCJA ELEKTRYCZNEGO SPRZĘTU GOSPODARSTWA D...
