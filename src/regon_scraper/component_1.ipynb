# %% [markdown]
# # Component 1 - REGON Scraper
#
# This module is used to scrape information from the [REGON database](https://wyszukiwarkaregon.stat.gov.pl/appBIR/index.aspx). The REGON database is a register of entities operating in Poland, including companies, institutions, and organizations.
#
# The module contains a class called "RegonScrapper" that is initialized with a [file path](test_data.txt). The class is used to create a web scraper that scrapes information about entities. The scraper is implemented using the Selenium package in Python, which allows for automated web browsing.
#
# The module also contains a function called "check_nip_regon_krs" that checks whether a given string is a valid NIP, REGON, or KRS number.
#
# Overall, the module can be used to automatically scrape information about entities operating in Poland from the REGON database, making it useful for research, data analysis, and other applications.

# %% [markdown]
# ## Case 1
# A simple example of the module's use. The input file contains one identifier - [input file](example.txt)

# %%
from component_1 import RegonScraper

scraper = RegonScraper('example.txt')

entities, local_entities, pkd = scraper.get_entity_info()
# Out:
# Download basic information about entities: 100%|█████████████████████████████████████████| 1/1 [00:09<00:00,  9.24s/it]

# %% [markdown]
# ### Legal/Physical entities

# %%
entities
# Out:
#        regon         nip                   nazwa  \
# 0  000001608  7770003699  POLITECHNIKA POZNAŃSKA
#
#   kod_i_nazwa_podstawowej_formy_prawnej kod_i_nazwa_szczegolnej_formy_prawnej  \
# 0                      1 - OSOBA PRAWNA                        044 - UCZELNIE
#
#                 kod_i_nazwa_formy_wlasnosci    kraj    wojewodztwo  powiat  \
# 0  112 - WŁASNOŚĆ PAŃSTWOWYCH OSÓB PRAWNYCH  POLSKA  WIELKOPOLSKIE  Poznań
#
#           gmina miejscowosc                         ulica nr_nieruchomosci  \
# 0  Poznań-Wilda      Poznań  pl. Marii Skłodowskiej-Curie                5
#
#   kod_pocztowy
# 0       60-965

# %% [markdown]
# ### Local entities

# %%
local_entities
# Out:
#             regon regon j.nadrzędnej nip j.nadrzędnej  \
# 0  00000160800032          000001608       7770003699
#
#                                                nazwa    kraj    wojewodztwo  \
# 0  ZESPÓŁ DZIAŁALNOŚCI GOSPODARCZEJ POLITECHNIKI ...  POLSKA  WIELKOPOLSKIE
#
#    powiat               gmina miejscowosc                  ulica  \
# 0  Poznań  Poznań-Nowe Miasto      Poznań  ul. Ludwika Zamenhofa
#
#   nr_nieruchomosci kod_pocztowy
# 0               26       60-965

# %% [markdown]
# ### PKD

# %%
pkd
# Out:
#             regon    kod                                     nazwa
# 0       000001608  8542Z                             SZKOŁY WYŻSZE
# 1  00000160800032  8532A                                  TECHNIKA
# 2  00000160800032  2562Z  OBRÓBKA MECHANICZNA ELEMENTÓW METALOWYCH
# 3  00000160800032  7111Z       DZIAŁALNOŚĆ W ZAKRESIE ARCHITEKTURY

# %% [markdown]
# ## Case 2
# A more complex example of module use. This time there are 7 identifiers of different types in the [input file.](test_data.txt)

# %%
from component_1 import RegonScraper

scraper = RegonScraper('test_data.txt')

entities, local_entities, pkd = scraper.get_entity_info()
# Out:
# Download basic information about entities: 100%|█████████████████████████████████████████| 7/7 [01:11<00:00, 10.16s/it]

# %%
entities
# Out:
#        regon         nip                                          nazwa  \
# 0  000001608  7770003699                         POLITECHNIKA POZNAŃSKA
# 1  000001554  5250005834                        POLITECHNIKA WARSZAWSKA
# 2  000001583  7270021895                            POLITECHNIKA ŁÓDZKA
# 3  000063650  5250009358                   INSTYTUT TECHNIKI BUDOWLANEJ
# 4  411347702  9231284232  GOSPODARSTWO ROLNE DARIUSZ GROCHOLEWSKI,TŁOKI
# 5  411347702  9231284232      UPRAWA GRZYBÓW DARIUSZ GROCHOLEWSKI,TŁOKI
#
#                kod_i_nazwa_podstawowej_formy_prawnej  \
# 0                                   1 - OSOBA PRAWNA
# 1                                   1 - OSOBA PRAWNA
# 2                                   1 - OSOBA PRAWNA
# 3                                   1 - OSOBA PRAWNA
# 4  9 - OSOBA FIZYCZNA PROWADZĄCA DZIAŁALNOŚĆ GOSP...
# 5  9 - OSOBA FIZYCZNA PROWADZĄCA DZIAŁALNOŚĆ GOSP...
#
#                kod_i_nazwa_szczegolnej_formy_prawnej  \
# 0                                     044 - UCZELNIE
# 1                                     044 - UCZELNIE
# 2                                     044 - UCZELNIE
# 3  165 - INSTYTUTY BADAWCZE I INSTYTUTY DZIAŁAJĄC...
# 4  099 - OSOBY FIZYCZNE PROWADZĄCE DZIAŁALNOŚĆ GO...
# 5  099 - OSOBY FIZYCZNE PROWADZĄCE DZIAŁALNOŚĆ GO...
#
#                 kod_i_nazwa_formy_wlasnosci    kraj    wojewodztwo  \
# 0  112 - WŁASNOŚĆ PAŃSTWOWYCH OSÓB PRAWNYCH  POLSKA  WIELKOPOLSKIE
# 1  112 - WŁASNOŚĆ PAŃSTWOWYCH OSÓB PRAWNYCH  POLSKA    MAZOWIECKIE
# 2  112 - WŁASNOŚĆ PAŃSTWOWYCH OSÓB PRAWNYCH  POLSKA        ŁÓDZKIE
# 3  112 - WŁASNOŚĆ PAŃSTWOWYCH OSÓB PRAWNYCH  POLSKA    MAZOWIECKIE
# 4  214 - WŁASNOŚĆ KRAJOWYCH OSÓB FIZYCZNYCH          WIELKOPOLSKIE
# 5  214 - WŁASNOŚĆ KRAJOWYCH OSÓB FIZYCZNYCH          WIELKOPOLSKIE
#
#         powiat         gmina miejscowosc                         ulica  \
# 0       Poznań  Poznań-Wilda      Poznań  pl. Marii Skłodowskiej-Curie
# 1     Warszawa   Śródmieście    Warszawa             Plac Politechniki
# 2         Łódź  Łódź-Polesie        Łódź       ul. Stefana Żeromskiego
# 3     Warszawa   Śródmieście    Warszawa                  ul. Filtrowa
# 4  wolsztyński      Wolsztyn       Tłoki
# 5  wolsztyński      Wolsztyn       Tłoki
#
#   nr_nieruchomosci kod_pocztowy
# 0                5       60-965
# 1                1       00-661
# 2              116       90-924
# 3                1       00-611
# 4              98A       64-200
# 5              98A       64-200

# %%
local_entities.head()
# Out:
#             regon regon j.nadrzędnej nip j.nadrzędnej  \
# 0  00000160800032          000001608       7770003699
# 1  00000155400020          000001554       5250005834
# 2  00000155400038          000001554       5250005834
# 3  41134770200020          411347702       9231284232
# 4  00006365000021          000063650       5250009358
#
#                                                nazwa    kraj    wojewodztwo  \
# 0  ZESPÓŁ DZIAŁALNOŚCI GOSPODARCZEJ POLITECHNIKI ...  POLSKA  WIELKOPOLSKIE
# 1             POLITECHNIKA WARSZAWSKA FILIA W PŁOCKU  POLSKA    MAZOWIECKIE
# 2       OFICYNA WYDAWNICZA POLITECHNIKI WARSZAWSKIEJ  POLSKA    MAZOWIECKIE
# 3          UPRAWA GRZYBÓW DARIUSZ GROCHOLEWSKI,TŁOKI  POLSKA  WIELKOPOLSKIE
# 4   INSTYTUT TECHNIKI BUDOWLANEJ ODDZIAŁ W GLIWICACH  POLSKA        ŚLĄSKIE
#
#         powiat               gmina miejscowosc                      ulica  \
# 0       Poznań  Poznań-Nowe Miasto      Poznań      ul. Ludwika Zamenhofa
# 1        Płock               Płock       Płock  ul. Ignacego Łukasiewicza
# 2     Warszawa         Śródmieście    Warszawa                  ul. Polna
# 3  wolsztyński            Wolsztyn       Tłoki
# 4      Gliwice             Gliwice     Gliwice             ul. Akademicka
#
#   nr_nieruchomosci kod_pocztowy
# 0               26       60-965
# 1               17       09-400
# 2               50       00-644
# 3              98A       64-200
# 4                5       44-101

# %%
pkd.head()
# Out:
#             regon    kod                                     nazwa
# 0       000001608  8542Z                             SZKOŁY WYŻSZE
# 1  00000160800032  8532A                                  TECHNIKA
# 2  00000160800032  2562Z  OBRÓBKA MECHANICZNA ELEMENTÓW METALOWYCH
# 3  00000160800032  7111Z       DZIAŁALNOŚĆ W ZAKRESIE ARCHITEKTURY
# 4       000001554  8542Z                             SZKOŁY WYŻSZE
